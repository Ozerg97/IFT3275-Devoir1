# %%
c = """
"""

# %%
def lignes_sur_une_ligne(texte):
    texte_sur_une_ligne = texte.replace("\n", " ")
    texte_sur_une_ligne = texte_sur_une_ligne.replace(" ", "")
    return texte_sur_une_ligne


c_ligne = lignes_sur_une_ligne(c)


print(c_ligne)
# Out:
# ...

# %%
def bits_to_ascii(bits):
    # Initialiser la chaîne de caractères ASCII résultante
    ascii_string = ''
    
    for i in range(0, len(bits), 8):
        byte = bits[i:i+8]
        byte_value = int(byte, 2)
        ascii_string += chr(byte_value)
    
    return ascii_string


ascii_result = bits_to_ascii(c_ligne)

# %%
mid_point = len(c_ligne) // 2  

C1 = c_ligne[:mid_point]
C2 = c_ligne[mid_point:]

# %%
def xor_bit_strings(s1, s2):
    if len(s1) != len(s2):
        raise ValueError("Les deux chaînes doivent avoir la même longueur")
    
    result = ''.join(str(int(a) ^ int(b)) for a, b in zip(s1, s2))
    
    return result

                   
C1_XOR_C2 = xor_bit_strings(C1, C2)


message = bits_to_ascii(C1_XOR_C2)

# %%
def text_to_ascii_binary(text):
    """Convertit une chaîne de texte en une chaîne de bits en utilisant ASCII."""
    binary_string = ''
    for char in text:
        if ord(char) < 128:  
            binary_string += format(ord(char), '08b')  
        else:
            raise ValueError(f"Le caractère '{char}' n'est pas dans la plage ASCII.")
    return binary_string

def xor_bits(bits1, bits2):
    """Effectue un XOR bit par bit entre deux chaînes de bits."""
    return ''.join(str(int(b1) ^ int(b2)) for b1, b2 in zip(bits1, bits2))



ciphertext_bits = xor_bits(C1, C2)
print(ciphertext_bits)


def crib_dragging_bits(ciphertext_bits, crib):
    crib_bits = text_to_ascii_binary(crib)
    for i in range(0, len(ciphertext_bits) - len(crib_bits) + 1, 8): 
        segment = ciphertext_bits[i:i+len(crib_bits)]
        xor_result_bits = xor_bits(segment, crib_bits)
        try:

            xor_result_text = ''.join(chr(int(xor_result_bits[i:i+8], 2)) for i in range(0, len(xor_result_bits), 8))
            print(f"Position {i//8}: {xor_result_text}")
        except ValueError:

            continue


crib = " dans "
crib_dragging_bits(ciphertext_bits, crib)
# Out:
# ...
# Position 0: K@ah'
# Position 1: dg:s'
# Position 2:  b5nt:
# Position 3: &0aii<
# Position 4: tdftos
# Position 5:  c{r p
# Position 6: '~}=#:
# Position 7: :x2>i$
# Position 8: <71tw#
# Position 9: s4{jp6
# Position 10: p~eme?
# Position 11: :`bxlm
# Position 12: $gwq>&
# Position 13: #r~#u+
# Position 14: 6{,hxt
# Position 15: ?)ge'
# Position 16: mbj:,{
# Position 17: &o51(k
# Position 18: +0>58
#
# Position 19: t;:%Y
# Position 20: ?*DF*
# Position 21: {/K[y
# Position 22: kNTds+
# Position 23:
# Qknx
# Position 24: naes"
# Position 25: *djnq4
# Position 26:  oalg?
# Position 27: +dczle
# Position 28:  fuq69
# Position 29: "p~+jo
# Position 30: 4{$w<5
# Position 31: ?!x!f=
# Position 32: e}.{ne
# Position 33: 9+ts6$
# Position 34: oq|+w&
# Position 35: 5y$ju
# Position 36: =!ehsm
# Position 37: e`gn>)
# Position 38: $ba#z/
# Position 39: &d,g|t
# Position 40:  )ha'Z
# Position 41: mmn:	a
# Position 42: )k52{
# Position 43: /0/(X
# Position 44: t 5C
# Position 45: Z%:!
# ...
